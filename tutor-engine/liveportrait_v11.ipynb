# %% [markdown]
# # Study Buddy V11 — LivePortrait Avatar
#
# This is the simpler avatar milestone. It uses the official LivePortrait human portrait-animation project and a Gradio share link instead of LiveTalking's WebRTC/UDP server.
#
# **Goal:** get a photorealistic teacher portrait visibly animated in the browser first. Voice, Groq, interruption, and the Study Buddy `/ai-face` integration come after this works.
#
# Colab GPU sessions are temporary. Do not put API keys or model weights into GitHub.

# %%
# !nvidia-smi
import torch, sys
print('Python:', sys.version)
print('PyTorch:', torch.__version__)
print('CUDA:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))
    print('VRAM GB:', round(torch.cuda.get_device_properties(0).total_memory / 1024**3, 2))

# %% [markdown]
# ## 1. Clone LivePortrait
#
# The official project supports a Gradio interface and a `--share` option, which avoids the LiveTalking WebRTC/UDP setup for this first visual test.

# %%
# %cd /content
# !rm -rf LivePortrait
# !git clone --depth 1 https://github.com/KlingAIResearch/LivePortrait.git
# %cd /content/LivePortrait

# %% [markdown]
# ## 2. Install dependencies and download the official human weights
#
# This follows the current official LivePortrait setup: Python environment dependencies plus the `KlingTeam/LivePortrait` pretrained weights.

# %%
# %cd /content/LivePortrait
# !pip -q install -r requirements.txt
# !pip -q install -U "huggingface_hub[cli]"
# !huggingface-cli download KlingTeam/LivePortrait --local-dir pretrained_weights --exclude "*.git*" "README.md" "docs"
print('LivePortrait dependencies and weights are ready.')

# %% [markdown]
# ## 3. Start the visual avatar demo
#
# This starts LivePortrait's human Gradio app with a public temporary share URL. The first model load can take a while. Keep this cell running.

# %%
# %cd /content/LivePortrait
# !python app.py --share --server_name 0.0.0.0

# %% [markdown]
# ## V11 target
#
# First prove the portrait animation visually. After that: microphone → speech recognition → Groq → TTS → talking-head engine → interruption → Study Buddy `/ai-face`.
#
# LivePortrait itself is a portrait-animation engine, not the final conversational speech stack.
